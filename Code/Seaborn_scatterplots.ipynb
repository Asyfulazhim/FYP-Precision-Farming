# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Dataset for analysis.csv')

# %%
df.head()
# Out:
#                                    date  temperature  humidity  soilMoisture  \
# 0  Wednesday,-December-20-2023-09:50:07         28.0        86         37.14
# 1  Wednesday,-December-20-2023-10:50:07         29.3        85         39.07
# 2  Wednesday,-December-20-2023-11:50:07         30.3        87         38.22
# 3  Wednesday,-December-20-2023-12:50:06         60.1        30         40.00
# 4  Wednesday,-December-20-2023-13:50:06         45.8        67         39.98
#
#    Length  Growth Fruit_Label
# 0   12.75    0.00     Fruit 1
# 1   12.76    0.01     Fruit 1
# 2   12.77    0.01     Fruit 1
# 3   12.78    0.01     Fruit 1
# 4   12.79    0.01     Fruit 1

# %%
sns.pairplot(df, hue = 'Fruit_abel')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\Udemy_ml\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sns.pairplot(df, hue = 'label')
#
# ...

# %%
plt.figure(figsize=(12,6),dpi=200)
sns.scatterplot(x='Length', y='Growth', data=df, hue='Fruit_Label')
plt.savefig("Fruit_plot.jpg")
