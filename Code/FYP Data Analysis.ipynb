# %%
import pandas as pd
import numpy as np

# %%
# Load data from the CSV file
file_path = 'FYP Data Result.csv'  # Replace with your file path
data = pd.read_csv(file_path)

# %%
data
# Out:
#                                       Date  temperature  Humidity  \
# 0    Wednesday,-December-20-2023-09:50:132         50.7        43
# 1    Wednesday,-December-20-2023-09:50:133         60.8        33
# 2    Wednesday,-December-20-2023-09:50:134         60.1        37
# 3    Wednesday,-December-20-2023-09:50:135         43.9        66
# 4    Wednesday,-December-20-2023-09:50:136         35.6        76
# ..                                     ...          ...       ...
# 102     Friday, January 05, 2024, 15:34:37         60.1        35
# 103     Friday, January 05, 2024, 16:34:47         60.1        28
# 104     Friday, January 05, 2024, 17:34:57         44.4        62
# 105     Friday, January 05, 2024, 18:35:09         39.0        67
# 106     Friday, January 05, 2024, 19:35:20         35.2        69
#
#      soilMoisture  Predicted_Length  Predicted_Growth  Actual_Length  \
# 0           34.48               NaN               NaN          13.00
# ...

# %%
# Assuming your CSV has columns named 'Actual_Length' and 'Predicted_Length'
actual_lengths = data['Actual_Length'].values
predicted_lengths = data['Predicted_Length'].values

# Calculate Mean Absolute Error (MAE)
mae = np.mean(np.abs(actual_lengths - predicted_lengths))
print("Mean Absolute Error (MAE):", mae)

# Calculate Mean Squared Error (MSE)
mse = np.mean((actual_lengths - predicted_lengths) ** 2)
print("Mean Squared Error (MSE):", mse)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Error (MAE): nan
# Mean Squared Error (MSE): nan
# Root Mean Squared Error (RMSE): nan

# %%
# Assuming your CSV has columns named 'Actual_Growth' and 'Predicted_Growth'
actual_growths = data['Actual_Growth'].values
predicted_growths = data['Predicted_Growth'].values

# Calculate Mean Absolute Error (MAE)
mae = np.mean(np.abs(actual_growths - predicted_growths))
print("Mean Absolute Error (MAE):", mae)

# Calculate Mean Squared Error (MSE)
mse = np.mean((actual_growths - predicted_growths) ** 2)
print("Mean Squared Error (MSE):", mse)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Error (MAE): nan
# Mean Squared Error (MSE): nan
# Root Mean Squared Error (RMSE): nan

# %%
# !pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# %%
# Set the style for the plot (optional)
sns.set(style="whitegrid")

# Create the plot
plt.figure(figsize=(10, 6))
sns.lineplot(x=data.index, y='Actual_Length', data=data, label='Actual Length', marker='o')
sns.lineplot(x=data.index, y='Predicted_Length', data=data, label='Predicted Length', marker='o')

# Set labels and title
plt.xlabel('Time in hour')
plt.ylabel('Length in mm')
plt.title('Actual Length vs Predicted Length Over Time')

# Show legend
plt.legend()

# Show the plot
plt.show()

# %%
plt.savefig("Predict_vs_actual1_plot.jpg")

# %%
# Assuming your CSV has columns named 'Actual_Length' and 'Predicted_Length'
actual_lengths = data['Actual_Length'].values
predicted_lengths2 = data['Predicted_Length2'].values

# Calculate Mean Absolute Error (MAE)
mae = np.mean(np.abs(actual_lengths - predicted_lengths2))
print("Mean Absolute Error (MAE):", mae)

# Calculate Mean Squared Error (MSE)
mse = np.mean((actual_lengths - predicted_lengths2) ** 2)
print("Mean Squared Error (MSE):", mse)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Error (MAE): 2.358808411214953
# Mean Squared Error (MSE): 7.466457851300914
# Root Mean Squared Error (RMSE): 2.7324819946892447

# %%
# Assuming your CSV has columns named 'Actual_Growth' and 'Predicted_Growth'
actual_growths = data['Actual_Growth'].values
predicted_growths2 = data['Predicted_Growth2'].values

# Calculate Mean Absolute Error (MAE)
mae = np.mean(np.abs(actual_growths - predicted_growths2))
print("Mean Absolute Error (MAE):", mae)

# Calculate Mean Squared Error (MSE)
mse = np.mean((actual_growths - predicted_growths2) ** 2)
print("Mean Squared Error (MSE):", mse)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)

growth_score = r2_score(actual_growths, predicted_growths2)
print("Growth score:", growth_score)
# Out:
# Mean Absolute Error (MAE): 0.1537772585607477
# Mean Squared Error (MSE): 0.052821950224219774
# Root Mean Squared Error (RMSE): 0.22983026394324088
# Growth score: 0.2327773848570832

# %%
# Set the style for the plot (optional)
sns.set(style="whitegrid")

# Create the plot
plt.figure(figsize=(10, 6))
sns.lineplot(x=data.index, y='Actual_Length', data=data, label='Actual Length', marker='o')
sns.lineplot(x=data.index, y='Predicted_Length2', data=data, label='Predicted Length2', marker='o')

# Set labels and title
plt.xlabel('Time in hour')
plt.ylabel('Length in mm')
plt.title('Actual Length vs Predicted Length Over Time')

# Show legend
plt.legend()

# Show the plot
plt.show()

# %%
file_path = 'FYP Data Result.csv'  # Replace with your file path
data1 = pd.read_csv(file_path)

# %%
data1
# Out:
#                                       Date  temperature  Humidity  \
# 0    Wednesday,-December-20-2023-09:50:132         50.7        43
# 1    Wednesday,-December-20-2023-09:50:133         60.8        33
# 2    Wednesday,-December-20-2023-09:50:134         60.1        37
# 3    Wednesday,-December-20-2023-09:50:135         43.9        66
# 4    Wednesday,-December-20-2023-09:50:136         35.6        76
# ..                                     ...          ...       ...
# 102     Friday, January 05, 2024, 15:34:37         60.1        35
# 103     Friday, January 05, 2024, 16:34:47         60.1        28
# 104     Friday, January 05, 2024, 17:34:57         44.4        62
# 105     Friday, January 05, 2024, 18:35:09         39.0        67
# 106     Friday, January 05, 2024, 19:35:20         35.2        69
#
#      soilMoisture  Predicted_Length  Predicted_Growth  Actual_Length  \
# 0           34.48               NaN               NaN          13.00
# ...

# %%
# Assuming your CSV has columns named 'Actual_Length' and 'Predicted_Length'
actual_lengths = data1['Actual_Length'].values
predicted_lengths2 = data1['Predicted_Length2'].values

# Calculate Mean Absolute Error (MAE)
mae = np.mean(np.abs(actual_lengths - predicted_lengths2))
print("Mean Absolute Error (MAE):", mae)

# Calculate Mean Squared Error (MSE)
mse = np.mean((actual_lengths - predicted_lengths2) ** 2)
print("Mean Squared Error (MSE):", mse)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)

length_score = r2_score(actual_lengths, predicted_lengths2)
print("Growth score:", length_score)
# Out:
# Mean Absolute Error (MAE): 2.358808411214953
# Mean Squared Error (MSE): 7.466457851300914
# Root Mean Squared Error (RMSE): 2.7324819946892447
# Growth score: 0.9837202255551617

# %%
# Assuming your CSV has columns named 'Actual_Growth' and 'Predicted_Growth'
actual_growths = data1['Actual_Growth'].values
predicted_growths2 = data1['Predicted_Growth2'].values

# Calculate Mean Absolute Error (MAE)
mae = np.mean(np.abs(actual_growths - predicted_growths2))
print("Mean Absolute Error (MAE):", mae)

# Calculate Mean Squared Error (MSE)
mse = np.mean((actual_growths - predicted_growths2) ** 2)
print("Mean Squared Error (MSE):", mse)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)

growth_score = r2_score(actual_growths, predicted_growths2)
print("Growth score:", growth_score)
# Out:
# Mean Absolute Error (MAE): 0.1537772585607477
# Mean Squared Error (MSE): 0.052821950224219774
# Root Mean Squared Error (RMSE): 0.22983026394324088
# Growth score: 0.2327773848570832

# %%
# Set the style for the plot (optional)
sns.set(style="whitegrid")

# Create the plot
plt.figure(figsize=(10, 6))
sns.lineplot(x=data1.index, y='Actual_Length', data=data1, label='Actual Length', marker='o')
sns.lineplot(x=data1.index, y='Predicted_Length2', data=data1, label='Predicted Length2', marker='o')

# Set labels and title
plt.xlabel('Time in hour')
plt.ylabel('Length in mm')
plt.title('Actual Length vs Predicted Length Over Time')

# Show legend
plt.legend()

# Show the plot
plt.show()

# %%
# Set the style for the plot (optional)
sns.set(style="whitegrid")

# Create the plot
plt.figure(figsize=(10, 6))
sns.lineplot(x=data1.index, y='Actual_Growth', data=data1, label='Actual Growth', marker='o')
sns.lineplot(x=data1.index, y='Predicted_Growth2', data=data1, label='Predicted Growth', marker='o')

# Set labels and title
plt.xlabel('Time in hour')
plt.ylabel('Length in mm')
plt.title('Actual Growth vs Predicted Growth Over Time')

# Show legend
plt.legend()

# Show the plot
plt.show()

# %%
from sklearn.metrics import r2_score

# %%
Actual_growth = data1['Actual_Growth']
Predicted_growth = data1['Predicted_Growth2']

r2 = r2_score(Actual_growth, Predicted_growth)

# Plotting the predicted vs actual values
plt.figure(figsize=(8, 6))
plt.scatter(Actual_growth, Predicted_growth, alpha=0.7, color='b', label='Actual vs Predicted')
plt.plot([min(Actual_growth), max(Actual_growth)], [min(Actual_growth), max(Actual_growth)], linestyle='--', color='r', label='Perfect Prediction')
plt.title(f'Model Accuracy: {r2:.2f}')
plt.xlabel('Actual Growth')
plt.ylabel('Predicted Growth')
plt.legend()
plt.show()

# %%
Actual_length = data1['Actual_Length']
Predicted_length = data1['Predicted_Length2']

r2 = r2_score(Actual_length, Predicted_length)

# Plotting the predicted vs actual values
plt.figure(figsize=(8, 6))
plt.scatter(Actual_length, Predicted_length, alpha=0.7, color='b', label='Actual vs Predicted')
plt.plot([min(Actual_length), max(Actual_length)], [min(Actual_length), max(Actual_length)], linestyle='--', color='r', label='Perfect Prediction')
plt.title(f'Model Accuracy: {r2:.2f}')
plt.xlabel('Actual Length in mm')
plt.ylabel('Predicted Length in mm')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_bar_graph(data, labels, title):
    fig, ax = plt.subplots()

    width = 0.25
    x = np.arange(len(labels))

    ax.bar(x - width, data['Abu']['Random Forest'], width, label='Random Forest - Abu')
    ax.bar(x - width, data['Abu']['Decision Tree'], width, label='Decision Tree - Abu')
    ax.bar(x - width, data['Abu']['KNN'], width, label='KNN - Abu')
    ax.bar(x - width, data['Abu']['SVM'], width, label='SVM - Abu')

    ax.bar(x + width, data['Bakar']['Random Forest'], width, label='Random Forest - Bakar')
    ax.bar(x + width, data['Bakar']['Decision Tree'], width, label='Decision Tree - Bakar')
    ax.bar(x + width, data['Bakar']['KNN'], width, label='KNN - Bakar')
    ax.bar(x + width, data['Bakar']['SVM'], width, label='SVM - Bakar')

    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.legend()

    ax.set_title(title)

    plt.tight_layout()
    plt.show()

data = {
    'Abu': {
        'Random Forest': 2,
        'Decision Tree': 4,
        'KNN': 6,
        'SVM': 8
    },
    'Bakar': {
        'Random Forest': 1,
        'Decision Tree': 3,
        'KNN': 5,
        'SVM': 7
    }
}

labels = ['Random Forest', 'Decision Tree', 'KNN', 'SVM']

plot_bar_graph(data, labels, 'Bar Graph with Two Labels (Abu and Bakar)')

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_bar_graph(data, labels, title):
    fig, ax = plt.subplots()

    width = 0.25
    x = np.arange(len(labels))

    ax.bar(x - width, data['Abu']['Random Forest'], width, label='Abu')
    ax.bar(x - width, data['Abu']['Decision Tree'], width, label='Abu')
    ax.bar(x - width, data['Abu']['KNN'], width, label='Abu')
    ax.bar(x - width, data['Abu']['SVM'], width, label='Abu')

    ax.bar(x + width, data['Bakar']['Random Forest'], width, label='Bakar')
    ax.bar(x + width, data['Bakar']['Decision Tree'], width, label='Bakar')
    ax.bar(x + width, data['Bakar']['KNN'], width, label='Bakar')
    ax.bar(x + width, data['Bakar']['SVM'], width, label='Bakar')

    ax.set_xticks(x)
    ax.set_xticklabels(labels)

    ax.set_title(title)

    plt.tight_layout()
    plt.show()

data = {
    'Abu': {
        'Random Forest': 2,
        'Decision Tree': 4,
        'KNN': 6,
        'SVM': 8
    },
    'Bakar': {
        'Random Forest': 1,
        'Decision Tree': 3,
        'KNN': 5,
        'SVM': 7
    }
}

labels = ['Random Forest', 'Decision Tree', 'KNN', 'SVM']

plot_bar_graph(data, labels, 'Bar Graph with Two Labels (Abu and Bakar)')

# %%
import numpy as np 
import matplotlib.pyplot as plt 

# set width of bar 
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8)) 

# set height of bar 
IT = [0.4053, 0.2275, 0.1672, 0.1478] 
ECE = [0.8556, 0.8301, 0.5608, 0.5606] 

# Set position of bar on X axis 
br1 = np.arange(len(IT)) 
br2 = [x + barWidth for x in br1] 
#br3 = [x + barWidth for x in br2] 

# Make the plot
plt.bar(br1, IT, color ='r', width = barWidth, 
		edgecolor ='grey', label ='Without length data') 
plt.bar(br2, ECE, color ='g', width = barWidth, 
		edgecolor ='grey', label ='With length data') 
#plt.bar(br3, CSE, color ='b', width = barWidth, 
#		edgecolor ='grey', label ='CSE') 

# Adding Xticks 
plt.xlabel('Model Score', fontweight ='bold', fontsize = 15) 
plt.ylabel('Value', fontweight ='bold', fontsize = 15) 
plt.xticks([r + barWidth for r in range(len(IT))], 
		['Random forest', 'Decision Tree', 'KNN', 'SVM'])

plt.legend()
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt 

# set width of bar 
barWidth = 0.25
fig, ax = plt.subplots(figsize=(12, 8)) 

# set height of bar 
IT = [0.4053, 0.2275, 0.2773, 0.1478] 
ECE = [0.8556, 0.8301, 0.5608, 0.5606] 

# Set position of bar on X axis 
br1 = np.arange(len(IT)) 
br2 = [x + barWidth for x in br1] 

# Make the plot
plt.bar(br1, IT, color ='r', width=barWidth, 
        edgecolor='grey', label='Case A') 
plt.bar(br2, ECE, color ='g', width=barWidth, 
        edgecolor='grey', label='Case B') 

# Adding data values on top of the bars
for i, v in enumerate(IT):
    ax.text(i, v + 0.02, str(v), color='black', ha='center', va='bottom', fontweight='bold')

for i, v in enumerate(ECE):
    ax.text(i + barWidth, v + 0.02, str(v), color='black', ha='center', va='bottom', fontweight='bold')

# Adding Xticks 
plt.xlabel('Model Score', fontweight='bold', fontsize=15) 
plt.ylabel('Value', fontweight='bold', fontsize=15) 
plt.xticks([r + barWidth/2 for r in range(len(IT))], 
           ['Random forest', 'Decision Tree', 'KNN', 'SVM'])

plt.legend()
plt.show()

# %%
zero_soil_moisture_rows = data1[data1['soilMoisture'] == 0]

# Print the rows where soilMoisture is 0
print(zero_soil_moisture_rows)
# Out:
#                                    Date  temperature  Humidity  soilMoisture  \
# 105  Friday, January 05, 2024, 18:35:09         39.0        67           0.0
#
#      Predicted_Length  Predicted_Growth  Actual_Length  Actual_Growth  \
# 105             82.37              0.76          86.25            1.3
#
#      Predicted_Length2  Predicted_Growth2  Unnamed: 10  Unnamed: 11  \
# 105              84.32               0.75          NaN          NaN
#
#      Unnamed: 12  Unnamed: 13  Unnamed: 14
# 105          NaN          NaN          NaN

# %%
rows_102_to_106 = data1.iloc[101:107]
print(rows_102_to_106)
# Out:
#                                    Date  temperature  Humidity  soilMoisture  \
# 101  Friday, January 05, 2024, 14:34:28         58.5        43         27.64
# 102  Friday, January 05, 2024, 15:34:37         60.1        35         16.70
# 103  Friday, January 05, 2024, 16:34:47         60.1        28         17.63
# 104  Friday, January 05, 2024, 17:34:57         44.4        62         16.53
# 105  Friday, January 05, 2024, 18:35:09         39.0        67          0.00
# 106  Friday, January 05, 2024, 19:35:20         35.2        69         43.52
#
#      Predicted_Length  Predicted_Growth  Actual_Length  Actual_Growth  \
# 101             78.69              1.08          81.00           0.85
# 102             79.74              1.05          82.30           1.30
# 103             80.78              1.04          83.60           1.30
# 104             81.61              0.83          84.95           1.35
# 105             82.37              0.76          86.25           1.30
# ...
